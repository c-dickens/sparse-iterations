# %% [markdown]
# # Sketch time comparison
#
# Comparing the sketch times of srht and countsketch on the same inputs.

# %%
import numpy as np
import scipy.sparse as sparse
import numba
from numba import jit
import matplotlib.pyplot as plt
import line_profiler
from tabulate import tabulate
# %load_ext line_profiler
# %matplotlib inline
from fht import fht

# %%
from countSketch import *
from srht import *

# %%
@jit(nopython=True)
def countSketch_elt_stream(matrixA, sketch_size):
    n,d = matrixA.shape
    sketch = np.zeros((sketch_size,d))
    nonzero_rows, nonzero_cols = np.nonzero(matrixA)
    hashedIndices = np.random.choice(sketch_size, n, replace=True)
    randSigns = np.random.choice(2, n, replace=True) * 2 - 1
    for ii,jj in zip(nonzero_rows,nonzero_cols):
        bucket = hashedIndices[ii]
        sketch[bucket, jj] += randSigns[ii]*matrixA[ii,jj]
    return sketch

# %%
matrix = sparse.random(2**16, 2**3, 0.1).toarray()
print(matrix.shape)
#matrix_sparse = matrix.tocsr()
#matrix = matrix.toarray()
#x = np.random.randn(matrix.shape[1])
#true_norm = np.linalg.norm(matrix@x,ord=2)**2
#cov_mat = matrix.T@matrix
#matrix_norm = np.linalg.norm(cov_mat, ord='fro')**2

sketch_size = 1000
# Out:
# (65536, 8)

# %%
# %timeit fht(matrix)
# Out:
# 16.2 ms ± 335 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %lprun -f srht_test srht_test(matrix)

# %%
# %lprun -f srht_transform srht_transform(matrix,sketch_size)

# %%
# %timeit srht_transform(matrix,sketch_size)
# Out:
# 20.7 ms ± 498 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit countSketchStreaming(matrix,sketch_size)
# Out:
# 71.9 ms ± 980 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %lprun -f countSketch_elt_stream countSketch_elt_stream(matrix, sketch_size)

# %%
import itertools
#from time import time
from timeit import default_timer as time
rows = [2**16, 2**17]
cols = [5, 10, 25, 50, 100]
density = [0.01, 0.1, 0.25, 0.5, 1.0]
sketch_sizes = [10*col for col in cols]

for n_rows, n_columns, data_density in itertools.product(rows, cols, density):
    sketch_size = sketch_sizes[cols.index(n_columns)]
    data = sparse.random(n_rows, n_columns, data_density).toarray()
    
    #print("(n,d) = ({},{})".format(n_rows,n_columns))
    
    start = time()
    hessian = data.T@data
    hessian_time = time() - start
    
    hessian_norm = np.linalg.norm(hessian,ord='fro')**2
    
    start = time()
    srht = srht_transform(data,sketch_size)
    srht_sketch_time = time() - start
    #print("SRHT sketch time: {}".format(srht_sketch_time))
    
    srht_hessian = srht.T@srht
    srht_hessian_norm = np.linalg.norm(srht_hessian,ord='fro')**2
    srht_hessian_error = srht_hessian_norm/hessian_norm
    #print("SRHT Hessian rel error: {}".format(srht_hessian_error))
    
    sketch_size = 100*sketch_size
    start = time()
    cwt = countSketch_elt_stream(data,sketch_size)
    cwt_sketch_time = time() - start
    cwt_hessian = cwt.T@cwt
    cwt_hessian_norm = np.linalg.norm(cwt_hessian,ord='fro')**2
    cwt_hessian_error = cwt_hessian_norm/hessian_norm
    
    print(tabulate([
        ['SRHT', n_rows, n_columns, data_density, srht_sketch_time, srht_hessian_error],
        ['CWT', '  ', '  ', '  ',  cwt_sketch_time, cwt_hessian_error]],
        headers=['Sketch', 'Rows', 'Cols', 'Density', 'Sketch time', 'Rel error'],
        tablefmt='orgtbl'))
    
    #start = time()
    #countSketchStreaming(data,sketch_size)
    #cwt_stream_sketch_time = time() - start
    
    #start = time()
    #countSketch_elt_stream(data,sketch_size)
    #cwtelt_stream_sketch_time = time() - start
    
    #print("Method: {} Rows: {} Cols: {} Sketch Size: {} Density: {} Time: {}".format(
    #    "SRHT", n_rows, n_columns, sketch_size, data_density, srht_sketch_time))
    
    #print("Method: {} Rows: {} Cols: {} Sketch Size: {} Density: {} Time: {}".format(
    #    "CWTR", n_rows, n_columns, sketch_size, data_density, cwt_stream_sketch_time))
    
    #print("Method: {} Rows: {} Cols: {} Sketch Size: {} Density: {} Time: {}".format(
    #    "CWTE", n_rows, n_columns, sketch_size, data_density, cwtelt_stream_sketch_time))
# Out:
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 5      | 0.01      |    0.01054    |    0.96833  |
# | CWT      |        |        |           |    0.00398369 |    0.980354 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 5      | 0.1       |    0.010353   |    1.24084  |
# | CWT      |        |        |           |    0.00362839 |    0.985926 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 5      | 0.25      |    0.0113303  |    1.2232   |
# | CWT      |        |        |           |    0.00469159 |    0.996993 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 5      | 0.5       |    0.00991647 |    0.697019 |
# | CWT      |        |        |           |    0.00573838 |    0.992971 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 5      | 1.0       |    0.00960727 |    0.877574 |
# | CWT      |        |        |           |    0.00534468 |    0.988797 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 10     | 0.01      |    0.0233266  |     1.16868 |
# | CWT      |        |        |           |    0.00400239 |     1.00292 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 10     | 0.1       |    0.020475   |    1.37664  |
# | CWT      |        |        |           |    0.00521448 |    0.993078 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 10     | 0.25      |    0.0211402  |    0.909688 |
# | CWT      |        |        |           |    0.00786018 |    0.997475 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 10     | 0.5       |    0.0191242  |    0.824329 |
# | CWT      |        |        |           |    0.00970177 |    1.00365  |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 10     | 1.0       |    0.0201224  |    1.24607  |
# | CWT      |        |        |           |    0.00948217 |    0.988739 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 25     | 0.01      |    0.0484497  |     1.14392 |
# | CWT      |        |        |           |    0.00613408 |     1.00547 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 25     | 0.1       |     0.0504321 |     1.22258 |
# | CWT      |        |        |           |     0.0110291 |     1.00037 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 25     | 0.25      |     0.0534262 |    1.06051  |
# | CWT      |        |        |           |     0.0187884 |    0.985071 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 25     | 0.5       |     0.0464888 |     1.04774 |
# | CWT      |        |        |           |     0.0246263 |     1.01161 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 25     | 1.0       |     0.0483424 |    1.22931  |
# | CWT      |        |        |           |     0.0233539 |    0.960188 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 50     | 0.01      |     0.10134   |     1.10131 |
# | CWT      |        |        |           |     0.0131027 |     1.00058 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 50     | 0.1       |     0.10732   |     1.09097 |
# | CWT      |        |        |           |     0.0227218 |     1.00446 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 50     | 0.25      |     0.0976793 |    0.886592 |
# | CWT      |        |        |           |     0.0363055 |    1.01552  |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 50     | 0.5       |     0.112439  |     1.03641 |
# | CWT      |        |        |           |     0.0607365 |     1.00886 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 50     | 1.0       |     0.0971281 |    0.975593 |
# | CWT      |        |        |           |     0.0488328 |    0.999198 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 100    | 0.01      |     0.202107  |     1.08533 |
# | CWT      |        |        |           |     0.0390643 |     1.00227 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 100    | 0.1       |      0.211188 |    1.11613  |
# | CWT      |        |        |           |      0.063398 |    0.999489 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 100    | 0.25      |     0.219102  |    0.875021 |
# | CWT      |        |        |           |     0.0886169 |    1.00465  |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 100    | 0.5       |      0.201415 |    0.946716 |
# | CWT      |        |        |           |      0.110226 |    1.00537  |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 65536  | 100    | 1.0       |      0.215133 |    1.1565   |
# | CWT      |        |        |           |      0.117173 |    0.994976 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 5      | 0.01      |    0.0248222  |     1.17293 |
# | CWT      |        |        |           |    0.00655048 |     1.00848 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 5      | 0.1       |    0.0207279  |    0.609671 |
# | CWT      |        |        |           |    0.00828748 |    1.0171   |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 5      | 0.25      |    0.0201901  |     1.20384 |
# | CWT      |        |        |           |    0.00992047 |     1.01785 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 5      | 0.5       |     0.0204426 |    0.947602 |
# | CWT      |        |        |           |     0.0121104 |    0.982953 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 5      | 1.0       |     0.0204901 |     0.53333 |
# | CWT      |        |        |           |     0.0107375 |     0.9172  |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 10     | 0.01      |    0.0404908  |    0.936938 |
# | CWT      |        |        |           |    0.00740898 |    1.00482  |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 10     | 0.1       |     0.040668  |    1.03148  |
# | CWT      |        |        |           |     0.0108907 |    0.989558 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 10     | 0.25      |     0.0450755 |    0.939524 |
# | CWT      |        |        |           |     0.0149536 |    0.993367 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 10     | 0.5       |     0.0386882 |    0.987169 |
# | CWT      |        |        |           |     0.0189165 |    1.01883  |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 10     | 1.0       |     0.0422096 |    0.796284 |
# | CWT      |        |        |           |     0.019186  |    0.964973 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 25     | 0.01      |     0.11898   |     1.12592 |
# | CWT      |        |        |           |     0.0114049 |     1.0012  |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 25     | 0.1       |     0.100234  |     1.02158 |
# | CWT      |        |        |           |     0.0216661 |     0.99777 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 25     | 0.25      |     0.0998326 |    1.1215   |
# | CWT      |        |        |           |     0.0352018 |    0.996823 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 25     | 0.5       |     0.116203  |    1.10596  |
# | CWT      |        |        |           |     0.0503601 |    0.981592 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 25     | 1.0       |     0.101888  |     0.80619 |
# | CWT      |        |        |           |     0.0531122 |     0.95613 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 50     | 0.01      |     0.226478  |    1.07762  |
# | CWT      |        |        |           |     0.0246353 |    0.998756 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 50     | 0.1       |     0.2186    |    0.995775 |
# | CWT      |        |        |           |     0.0447355 |    0.999969 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 50     | 0.25      |     0.223545  |    0.875081 |
# | CWT      |        |        |           |     0.0646985 |    0.997133 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 50     | 0.5       |     0.216074  |    0.940569 |
# | CWT      |        |        |           |     0.0938176 |    1.01068  |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 50     | 1.0       |     0.220606  |    1.0899   |
# | CWT      |        |        |           |     0.0992082 |    0.984256 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 100    | 0.01      |     0.422234  |     1.09674 |
# | CWT      |        |        |           |     0.0568954 |     1.00085 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 100    | 0.1       |      0.421218 |     1.04482 |
# | CWT      |        |        |           |      0.100794 |     1.009   |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 100    | 0.25      |      0.48162  |    1.04884  |
# | CWT      |        |        |           |      0.156128 |    0.984676 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 100    | 0.5       |      0.478676 |     1.21165 |
# | CWT      |        |        |           |      0.195304 |     1.00178 |
# | Sketch   | Rows   | Cols   | Density   |   Sketch time |   Rel error |
# |----------+--------+--------+-----------+---------------+-------------|
# | SRHT     | 131072 | 100    | 1.0       |      0.517954 |    0.915736 |
# | CWT      |        |        |           |      0.209616 |    0.991729 |

# %%
# Test the norm of the returned values

rows = [25000, 50000]
cols = [10, 100, 500]
density = [0.01, 0.1, 0.25, 0.5, 1.0]
sketch_sizes = [10*col for col in cols]

for n_rows, n_columns, data_density in itertools.product(rows, cols, density):
    sketch_size = sketch_sizes[cols.index(n_columns)]
    data = sparse.random(n_rows, n_columns, data_density).toarray()
    test_vector = np.random.randn(data.shape[1])
    true_mat_vec_norm = np.linalg.norm(data@test_vector)**2
    true_covariance_norm = np.linalg.norm(data.T@data)**2
    
    SRHT = srht_transform(data,sketch_size)
    SRHT_vec_norm = np.linalg.norm(SRHT@test_vector)**2
    SRHT_mat_norm = np.linalg.norm(SRHT.T@SRHT)**2
    SRHT_vec_rel_error = SRHT_vec_norm/true_mat_vec_norm
    SRHT_mat_rel_error = SRHT_mat_norm/true_covariance_norm
    
    CWTE = countSketch_elt_stream(data,sketch_size)
    CWTE_vec_norm = np.linalg.norm(CWTE@test_vector)**2
    CWTE_mat_norm = np.linalg.norm(CWTE.T@CWTE)**2
    CWTE_vec_rel_error = CWTE_vec_norm/true_mat_vec_norm
    CWTE_mat_rel_error = CWTE_mat_norm/true_covariance_norm
    
    print("{} Rows: {} Cols: {} Sketch Size: {} Density: {} Vec norm: {} Mat norm: {}".format(
        "SRHT", n_rows, n_columns, sketch_size, data_density, SRHT_vec_rel_error, SRHT_mat_rel_error))
    
    print("{} Rows: {} Cols: {} Sketch Size: {} Density: {} Vec norm: {} Mat norm: {}".format(
        "CWTE", n_rows, n_columns, sketch_size, data_density, CWTE_vec_rel_error, CWTE_mat_rel_error))
# Out:
# SRHT Rows: 25000 Cols: 10 Sketch Size: 100 Density: 0.01 Vec norm: 1.1312787102561204 Mat norm: 1.0647174236549088
# CWTE Rows: 25000 Cols: 10 Sketch Size: 100 Density: 0.01 Vec norm: 1.0222613846662432 Mat norm: 1.0575537057519346
# SRHT Rows: 25000 Cols: 10 Sketch Size: 100 Density: 0.1 Vec norm: 0.9318728694310383 Mat norm: 1.0984999808816736
# CWTE Rows: 25000 Cols: 10 Sketch Size: 100 Density: 0.1 Vec norm: 1.033499901432821 Mat norm: 1.218831713447632
# SRHT Rows: 25000 Cols: 10 Sketch Size: 100 Density: 0.25 Vec norm: 0.8360495801472566 Mat norm: 1.2195216649701677
# CWTE Rows: 25000 Cols: 10 Sketch Size: 100 Density: 0.25 Vec norm: 0.820159969582668 Mat norm: 1.0416515376042939
# SRHT Rows: 25000 Cols: 10 Sketch Size: 100 Density: 0.5 Vec norm: 0.8282833419088235 Mat norm: 1.007109517702544
# CWTE Rows: 25000 Cols: 10 Sketch Size: 100 Density: 0.5 Vec norm: 1.0335206199259088 Mat norm: 0.954980780886542
# SRHT Rows: 25000 Cols: 10 Sketch Size: 100 Density: 1.0 Vec norm: 0.9153791999218154 Mat norm: 0.707071403013553
# CWTE Rows: 25000 Cols: 10 Sketch Size: 100 Density: 1.0 Vec norm: 0.8578296618874299 Mat norm: 0.6935406072484706
# SRHT Rows: 25000 Cols: 100 Sketch Size: 1000 Density: 0.01 Vec norm: 0.934158058057216 Mat norm: 1.0627998888278944
# CWTE Rows: 25000 Cols: 100 Sketch Size: 1000 Density: 0.01 Vec norm: 0.8770394559564764 Mat norm: 1.092922050463229
# SRHT Rows: 25000 Cols: 100 Sketch Size: 1000 Density: 0.1 Vec norm: 1.0649666810611773 Mat norm: 1.0624508127299832
# CWTE Rows: 25000 Cols: 100 Sketch Size: 1000 Density: 0.1 Vec norm: 0.9730856584493581 Mat norm: 1.0485985476101098
# SRHT Rows: 25000 Cols: 100 Sketch Size: 1000 Density: 0.25 Vec norm: 1.0158416006662374 Mat norm: 1.0297312289857155
# CWTE Rows: 25000 Cols: 100 Sketch Size: 1000 Density: 0.25 Vec norm: 0.9068570586207058 Mat norm: 1.0063836100652361
# SRHT Rows: 25000 Cols: 100 Sketch Size: 1000 Density: 0.5 Vec norm: 1.033781617827524 Mat norm: 1.0389824247851482
# CWTE Rows: 25000 Cols: 100 Sketch Size: 1000 Density: 0.5 Vec norm: 1.1245938583644484 Mat norm: 1.2776198700605228
# SRHT Rows: 25000 Cols: 100 Sketch Size: 1000 Density: 1.0 Vec norm: 1.0222867368002457 Mat norm: 0.9800979643216079
# CWTE Rows: 25000 Cols: 100 Sketch Size: 1000 Density: 1.0 Vec norm: 1.0051128798876026 Mat norm: 0.9452789212365754
# SRHT Rows: 25000 Cols: 500 Sketch Size: 5000 Density: 0.01 Vec norm: 1.003292917813454 Mat norm: 1.077926186855308
# CWTE Rows: 25000 Cols: 500 Sketch Size: 5000 Density: 0.01 Vec norm: 1.0279977594423966 Mat norm: 1.0963650869226926
# SRHT Rows: 25000 Cols: 500 Sketch Size: 5000 Density: 0.1 Vec norm: 1.0021181113038105 Mat norm: 1.1101867107296084
# CWTE Rows: 25000 Cols: 500 Sketch Size: 5000 Density: 0.1 Vec norm: 1.0289679437590913 Mat norm: 1.0315581990218534
# SRHT Rows: 25000 Cols: 500 Sketch Size: 5000 Density: 0.25 Vec norm: 0.9791827926338383 Mat norm: 0.9180604941531135
# CWTE Rows: 25000 Cols: 500 Sketch Size: 5000 Density: 0.25 Vec norm: 0.9690430738280131 Mat norm: 1.0183804432703203
# SRHT Rows: 25000 Cols: 500 Sketch Size: 5000 Density: 0.5 Vec norm: 1.0117753587999274 Mat norm: 1.0187584321716079
# CWTE Rows: 25000 Cols: 500 Sketch Size: 5000 Density: 0.5 Vec norm: 1.0103226750608922 Mat norm: 1.0021263888430372
# SRHT Rows: 25000 Cols: 500 Sketch Size: 5000 Density: 1.0 Vec norm: 1.015258958719759 Mat norm: 1.0134480598973912
# CWTE Rows: 25000 Cols: 500 Sketch Size: 5000 Density: 1.0 Vec norm: 1.0413326507380651 Mat norm: 0.9589550279093186
# SRHT Rows: 50000 Cols: 10 Sketch Size: 100 Density: 0.01 Vec norm: 1.0570494476907126 Mat norm: 1.1857959802532787
# CWTE Rows: 50000 Cols: 10 Sketch Size: 100 Density: 0.01 Vec norm: 0.9789168696661671 Mat norm: 1.1192825425333168
# SRHT Rows: 50000 Cols: 10 Sketch Size: 100 Density: 0.1 Vec norm: 0.9648379780370216 Mat norm: 1.2048151195770562
# CWTE Rows: 50000 Cols: 10 Sketch Size: 100 Density: 0.1 Vec norm: 0.940464182385333 Mat norm: 1.1193055045419162
# SRHT Rows: 50000 Cols: 10 Sketch Size: 100 Density: 0.25 Vec norm: 0.921098925169235 Mat norm: 0.8502176559659359
# CWTE Rows: 50000 Cols: 10 Sketch Size: 100 Density: 0.25 Vec norm: 1.1388485444771326 Mat norm: 1.1859207769992122
# SRHT Rows: 50000 Cols: 10 Sketch Size: 100 Density: 0.5 Vec norm: 1.0504110164956963 Mat norm: 1.1774122093266304
# CWTE Rows: 50000 Cols: 10 Sketch Size: 100 Density: 0.5 Vec norm: 0.8977802462900789 Mat norm: 1.067939880244508
# SRHT Rows: 50000 Cols: 10 Sketch Size: 100 Density: 1.0 Vec norm: 1.0192780478654133 Mat norm: 0.6976013826130852
# CWTE Rows: 50000 Cols: 10 Sketch Size: 100 Density: 1.0 Vec norm: 1.0141812522813103 Mat norm: 1.1863354212923773
# SRHT Rows: 50000 Cols: 100 Sketch Size: 1000 Density: 0.01 Vec norm: 1.0322219781243467 Mat norm: 1.0805268253761864
# CWTE Rows: 50000 Cols: 100 Sketch Size: 1000 Density: 0.01 Vec norm: 0.9856594291175372 Mat norm: 1.1086924984638051
# SRHT Rows: 50000 Cols: 100 Sketch Size: 1000 Density: 0.1 Vec norm: 1.0122723729366407 Mat norm: 1.0272737657698627
# CWTE Rows: 50000 Cols: 100 Sketch Size: 1000 Density: 0.1 Vec norm: 0.9389354566362298 Mat norm: 1.0535456659177873
# SRHT Rows: 50000 Cols: 100 Sketch Size: 1000 Density: 0.25 Vec norm: 1.0774806930740572 Mat norm: 0.9981950276710277
# CWTE Rows: 50000 Cols: 100 Sketch Size: 1000 Density: 0.25 Vec norm: 1.0467779987039023 Mat norm: 0.9159597600421219
# SRHT Rows: 50000 Cols: 100 Sketch Size: 1000 Density: 0.5 Vec norm: 1.0332278457750352 Mat norm: 1.0835886589637589
# CWTE Rows: 50000 Cols: 100 Sketch Size: 1000 Density: 0.5 Vec norm: 0.9938495285497702 Mat norm: 0.9842275953202883
# SRHT Rows: 50000 Cols: 100 Sketch Size: 1000 Density: 1.0 Vec norm: 0.9424761978519745 Mat norm: 1.0154281608974531
# CWTE Rows: 50000 Cols: 100 Sketch Size: 1000 Density: 1.0 Vec norm: 0.9838253685366233 Mat norm: 0.9500945780985401
# SRHT Rows: 50000 Cols: 500 Sketch Size: 5000 Density: 0.01 Vec norm: 1.0225360656494111 Mat norm: 1.091275097482939
# CWTE Rows: 50000 Cols: 500 Sketch Size: 5000 Density: 0.01 Vec norm: 0.9864838099448416 Mat norm: 1.097632777320429
# SRHT Rows: 50000 Cols: 500 Sketch Size: 5000 Density: 0.1 Vec norm: 0.9991555869430041 Mat norm: 0.9629961123014391
# CWTE Rows: 50000 Cols: 500 Sketch Size: 5000 Density: 0.1 Vec norm: 1.0200529387556736 Mat norm: 1.0797008958682686
# SRHT Rows: 50000 Cols: 500 Sketch Size: 5000 Density: 0.25 Vec norm: 0.9993477809636266 Mat norm: 0.9587974509915803
# CWTE Rows: 50000 Cols: 500 Sketch Size: 5000 Density: 0.25 Vec norm: 0.9973604643687944 Mat norm: 1.0189999682093747
# SRHT Rows: 50000 Cols: 500 Sketch Size: 5000 Density: 0.5 Vec norm: 0.974485254163715 Mat norm: 0.9703814601395158
# CWTE Rows: 50000 Cols: 500 Sketch Size: 5000 Density: 0.5 Vec norm: 0.9890598984978615 Mat norm: 0.9902005519162522
# SRHT Rows: 50000 Cols: 500 Sketch Size: 5000 Density: 1.0 Vec norm: 0.9604119370668343 Mat norm: 0.9316198985129464
# CWTE Rows: 50000 Cols: 500 Sketch Size: 5000 Density: 1.0 Vec norm: 1.0161187587518377 Mat norm: 1.0065622515925574
